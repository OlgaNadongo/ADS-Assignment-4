# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##importing data
tel=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
tel.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
##Getting to understand data
tel.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
tel.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
tel.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
##Checking for missing values
tel.isna().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %% [markdown]
# # 1. Demographic:
#  ## a.Which 2 demographics have proven to be the most popular with the telco brand?

# %%
tel.SeniorCitizen.value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
tel.Partner.value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
tel.Dependents.value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
tel.gender.value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
##The two demographics that are most popular with the telco brand are non-senior citizens and also those without any known dependants.

# %% [markdown]
# # b. If the marketing team wanted to increase customer retention, to whom should they target their advertisements to?

# %%
tel.groupby(["SeniorCitizen", "Partner", "Dependents","gender","Churn" ]).size().unstack()
# Out:
# Churn                                     No  Yes
# SeniorCitizen Partner Dependents gender
# 0             No      No         Female  909  429
#                                  Male    963  418
#                       Yes        Female  110   32
#                                  Male    168   43
#               Yes     No         Female  482  114
#                                  Male    439  128
#                       Yes        Female  720  124
#                                  Male    717  105
# 1             No      No         Female  159  158
#                                  Male    126  118
#                       Yes        Female    2    1
#                                  Male      4    1
#               Yes     No         Female  136   73
#                                  Male    176  105
#                       Yes        Female   31    8
#                                  Male     32   12

# %%
##To increase customer retention, the marketing team should focus on individuals who are not senior citizens, have neither dependants nor any known partners.Indivuals with the qualities mentioned before could be either males or females however much emphasis should on the females as they are the largest number to leave as shown above.

# %% [markdown]
# # 2. Services:
#
# a. Which 3 services are contributing to a higher monthly charge and resulting to
# customers churning? (Use visualizations in explaining your analysis)

# %%
tel.groupby(["PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","Churn" ]).size().unstack()
# Out:
# Churn                                                                                                                                                                     No  \
# PhoneService MultipleLines    InternetService OnlineSecurity      OnlineBackup        DeviceProtection    TechSupport         StreamingTV         StreamingMovies
# No           No phone service DSL             No                  No                  No                  No                  No                  No                    45.0
#                                                                                                                                                   Yes                    5.0
#                                                                                                                               Yes                 No                     5.0
# ...

# %%
service=tel[["PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies"]]
print(service)
# Out:
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0             Yes               No          No          No              No
# ...

# %%
tel.groupby(["service","churn"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-4f2b1750e750> in <module>
# ----> 1 tel.groupby(["service","churn"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ...
